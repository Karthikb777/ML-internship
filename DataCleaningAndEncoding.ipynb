# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('rawData.csv')
data.head()
# Out:
#   Customer ID               Name Gender  Age  Income (USD) Income Stability  \
# 0     C-36995   Frederica Shealy      F   56       1933.05              Low
# 1     C-33999  America Calderone      M   32       4952.91              Low
# 2      C-3770      Rosetta Verne      F   65        988.19             High
# 3     C-26480         Zoe Chitty      F   65           NaN             High
# 4     C-23459       Afton Venema      F   31       2614.77              Low
#
#   Profession     Type of Employment    Location  Loan Amount Request (USD)  \
# 0    Working            Sales staff  Semi-Urban                   72809.58
# 1    Working                    NaN  Semi-Urban                   46837.47
# 2  Pensioner                    NaN  Semi-Urban                   45593.04
# 3  Pensioner                    NaN       Rural                   80057.92
# 4    Working  High skill tech staff  Semi-Urban                  113858.89
#
# ...

# %%
# description of the data
data.describe()
# Out:
#                 Age  Income (USD)  Loan Amount Request (USD)  \
# count  30000.000000  2.542400e+04               30000.000000
# mean      40.092300  2.630574e+03               88826.333855
# std       16.045129  1.126272e+04               59536.949605
# min       18.000000  3.777000e+02                6048.240000
# 25%       25.000000  1.650457e+03               41177.755000
# 50%       40.000000  2.222435e+03               75128.075000
# 75%       55.000000  3.090593e+03              119964.605000
# max       65.000000  1.777460e+06              621497.820000
#
#        Current Loan Expenses (USD)    Dependents  Credit Score  \
# count                 29828.000000  27507.000000  28297.000000
# mean                    400.936876      2.253027    739.885381
# std                     242.545375      0.951162     72.163846
# min                    -999.000000      1.000000    580.000000
# 25%                     247.667500      2.000000    681.880000
# ...

# %% [markdown]
# ## 4 columns have a negative value that needs to be cleaned.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer ID                  30000 non-null  object
#  1   Name                         30000 non-null  object
#  2   Gender                       29947 non-null  object
#  3   Age                          30000 non-null  int64
#  4   Income (USD)                 25424 non-null  float64
#  5   Income Stability             28317 non-null  object
#  6   Profession                   30000 non-null  object
#  7   Type of Employment           22730 non-null  object
#  8   Location                     30000 non-null  object
#  9   Loan Amount Request (USD)    30000 non-null  float64
#  10  Current Loan Expenses (USD)  29828 non-null  float64
#  11  Expense Type 1               30000 non-null  object
#  12  Expense Type 2               30000 non-null  object
# ...

# %% [markdown]
# ## Discarding of unnecessary and unique data
# ### we will get rid of unnecessary data and unique data like IDs.

# %%
data.drop(columns=['Customer ID', 'Name', 'Gender', 'Profession', 'Property ID', 'Property Type', 'Property Age'], inplace=True)
data
# Out:
#        Age  Income (USD) Income Stability     Type of Employment    Location  \
# 0       56       1933.05              Low            Sales staff  Semi-Urban
# 1       32       4952.91              Low                    NaN  Semi-Urban
# 2       65        988.19             High                    NaN  Semi-Urban
# 3       65           NaN             High                    NaN       Rural
# 4       31       2614.77              Low  High skill tech staff  Semi-Urban
# ...    ...           ...              ...                    ...         ...
# 29995   38       4969.41              Low               Managers       Urban
# 29996   20       1606.88              Low               Laborers  Semi-Urban
# 29997   49           NaN              Low            Sales staff       Urban
# 29998   38       2417.71              Low         Security staff  Semi-Urban
# 29999   63       3068.24             High                    NaN       Rural
#
# ...

# %% [markdown]
# ## checking for and handling NaN values

# %%
data.isnull().sum()
# Out:
# Age                               0
# Income (USD)                   4576
# Income Stability               1683
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2493
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %% [markdown]
# ### we can see that there are NaN values in many fields.

# %%
# cols = data.columns.to_list()

# for col in cols:
#     data[col] = data[col].fillna(value=data[col].mode())

# # data = data.fillna(method='bfill')

data = data.dropna()
data.isnull().sum()
# Out:
# Age                            0
# Income (USD)                   0
# Income Stability               0
# Type of Employment             0
# Location                       0
# Loan Amount Request (USD)      0
# Current Loan Expenses (USD)    0
# Expense Type 1                 0
# Expense Type 2                 0
# Dependents                     0
# Credit Score                   0
# No. of Defaults                0
# Has Active Credit Card         0
# Property Location              0
# Co-Applicant                   0
# Property Price                 0
# Loan Sanction Amount (USD)     0
# dtype: int64

# %% [markdown]
# ## Handling negative values

# %%
data.describe()
# Out:
#                 Age  Income (USD)  Loan Amount Request (USD)  \
# count  15199.000000  1.519900e+04               15199.000000
# mean      37.809527  2.682684e+03               87571.963783
# std       14.983672  1.447330e+04               58030.109853
# min       18.000000  3.777000e+02                6048.240000
# 25%       23.000000  1.668220e+03               41089.230000
# 50%       37.000000  2.245940e+03               74541.800000
# 75%       51.000000  3.105470e+03              118622.600000
# max       64.000000  1.777460e+06              447860.560000
#
#        Current Loan Expenses (USD)    Dependents  Credit Score  \
# count                 15199.000000  15199.000000  15199.000000
# mean                    404.272359      2.323048    731.817974
# std                     232.852092      0.971899     70.061824
# min                    -999.000000      1.000000    582.300000
# 25%                     253.460000      2.000000    675.105000
# ...

# %%
cols_with_negative_vals = ['Current Loan Expenses (USD)', 'Co-Applicant', 'Property Price', 'Loan Sanction Amount (USD)']

for col in cols_with_negative_vals:
    data[col] = np.where(data[col] <= 0, np.nan, data[col])

data['Co-Applicant'] = np.where(data['Co-Applicant'] <= 0, data['Co-Applicant'].mean(), data['Co-Applicant'])

# data['Co-Applicant'].min()
data.describe()
data.dropna(how='any', axis=0)

data.isnull().sum()

# TODO: HANDLE THIS
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_14024/2646151296.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = np.where(data[col] <= 0, np.nan, data[col])
# C:\Users\user\AppData\Local\Temp/ipykernel_14024/2646151296.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Co-Applicant'] = np.where(data['Co-Applicant'] <= 0, data['Co-Applicant'].mean(), data['Co-Applicant'])
# Age                               0
# Income (USD)                      0
# ...

# %%
# data['Current Loan Expenses (USD)'] = data['Current Loan Expenses (USD
data = data.dropna(how='any', axis=0)
data.isnull().sum()
# Out:
# Age                            0
# Income (USD)                   0
# Income Stability               0
# Type of Employment             0
# Location                       0
# Loan Amount Request (USD)      0
# Current Loan Expenses (USD)    0
# Expense Type 1                 0
# Expense Type 2                 0
# Dependents                     0
# Credit Score                   0
# No. of Defaults                0
# Has Active Credit Card         0
# Property Location              0
# Co-Applicant                   0
# Property Price                 0
# Loan Sanction Amount (USD)     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

cols = data.select_dtypes(include=['object'])
cols.head(10)

for col in cols:
    data[col] = le.fit_transform(data[col])

data
# Out:
#        Age  Income (USD)  Income Stability  Type of Employment  Location  \
# 5       60       1234.92                 0                  15         0
# 8       38       1296.07                 0                   2         0
# 10      18       2416.86                 0                   3         1
# 14      61       1664.52                 0                   3         1
# 15      54       3716.54                 0                   4         0
# ...    ...           ...               ...                 ...       ...
# 29985   18       3593.59                 0                   4         1
# 29986   32       8308.27                 0                  10         2
# 29995   38       4969.41                 0                  10         2
# 29996   20       1606.88                 0                   8         1
# 29998   38       2417.71                 0                  16         1
#
#        Loan Amount Request (USD)  Current Loan Expenses (USD)  Expense Type 1  \
# ...

# %%
# saving the data to a csv file
data.to_csv('./encoded data/enc3.csv')
