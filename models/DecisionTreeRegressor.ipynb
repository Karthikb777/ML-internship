# %%
import numpy as np
import pandas as pd

# %%
# importing the dataset to train and test
data = pd.read_csv('../encoded data/enc1.csv')
data
# Out:
#        Unnamed: 0  Age  Income (USD)  Income Stability  Type of Employment  \
# 0               0   56       1933.05                 1                  14
# 1               1   32       4952.91                 1                   6
# 2               3   65       2614.77                 0                   6
# 3               4   31       2614.77                 1                   6
# 4               5   60       1234.92                 1                  15
# ...           ...  ...           ...               ...                 ...
# 20058       29995   38       4969.41                 1                  10
# 20059       29996   20       1606.88                 1                   8
# 20060       29997   49       2417.71                 1                  14
# 20061       29998   38       2417.71                 1                  16
# 20062       29999   63       3068.24                 0                  18
#
#        Location  Loan Amount Request (USD)  Current Loan Expenses (USD)  \
# 0             1                   72809.58                       241.08
# 1             1                   46837.47                       495.81
# 2             0                   80057.92                       298.54
# 3             1                  113858.89                       491.41
# 4             0                   34434.72                       181.48
# ...         ...                        ...                          ...
# 20058         2                   76657.90                       722.34
# 20059         1                   66595.14                       253.04
# 20060         2                   81410.08                       583.11
# 20061         1                  142524.10                       378.29
# 20062         0                  156290.54                       693.94
#
#        Expense Type 1  Expense Type 2  Dependents  Credit Score  \
# 0                   0               0         3.0        809.44
# 1                   0               1         1.0        780.40
# 2                   0               1         2.0        832.70
# 3                   0               1         2.0        745.55
# 4                   0               0         2.0        684.12
# ...               ...             ...         ...           ...
# 20058               1               1         2.0        869.61
# 20059               0               0         3.0        729.41
# 20060               0               1         3.0        677.27
# 20061               0               1         3.0        677.27
# 20062               0               1         1.0        815.44
#
#        No. of Defaults  Has Active Credit Card  Property Location  \
# 0                    0                       2                  0
# 1                    0                       2                  0
# 2                    1                       2                  1
# 3                    1                       0                  1
# 4                    1                       1                  0
# ...                ...                     ...                ...
# 20058                0                       2                  2
# 20059                0                       1                  2
# 20060                0                       0                  0
# 20061                1                       2                  2
# 20062                0                       0                  0
#
#        Co-Applicant  Property Price  Loan Sanction Amount (USD)
# 0               1.0       119933.46                    54607.18
# 1               1.0        54791.00                    37469.98
# 2               1.0       121441.51                    56040.54
# 3               1.0       208567.91                    74008.28
# 4               1.0        43146.82                    22382.57
# ...             ...             ...                         ...
# 20058           1.0       111096.56                    68992.11
# 20059           1.0        73453.94                    46616.60
# 20060           1.0       102108.02                    61057.56
# 20061           1.0       168194.47                    99766.87
# 20062           1.0       194512.60                   117217.90
#
# [20063 rows x 18 columns]

# %%
# importing the decision tree regressor from sklearn
from sklearn.tree import DecisionTreeRegressor

DTR = DecisionTreeRegressor()

# %%
# defining the independent variables
X = data.drop(['Loan Sanction Amount (USD)', 'Unnamed: 0'], axis=1)
X
# Out:
#        Age  Income (USD)  Income Stability  Type of Employment  Location  \
# 0       56       1933.05                 1                  14         1
# 1       32       4952.91                 1                   6         1
# 2       65       2614.77                 0                   6         0
# 3       31       2614.77                 1                   6         1
# 4       60       1234.92                 1                  15         0
# ...    ...           ...               ...                 ...       ...
# 20058   38       4969.41                 1                  10         2
# 20059   20       1606.88                 1                   8         1
# 20060   49       2417.71                 1                  14         2
# 20061   38       2417.71                 1                  16         1
# 20062   63       3068.24                 0                  18         0
#
#        Loan Amount Request (USD)  Current Loan Expenses (USD)  Expense Type 1  \
# 0                       72809.58                       241.08               0
# 1                       46837.47                       495.81               0
# 2                       80057.92                       298.54               0
# 3                      113858.89                       491.41               0
# 4                       34434.72                       181.48               0
# ...                          ...                          ...             ...
# 20058                   76657.90                       722.34               1
# 20059                   66595.14                       253.04               0
# 20060                   81410.08                       583.11               0
# 20061                  142524.10                       378.29               0
# 20062                  156290.54                       693.94               0
#
#        Expense Type 2  Dependents  Credit Score  No. of Defaults  \
# 0                   0         3.0        809.44                0
# 1                   1         1.0        780.40                0
# 2                   1         2.0        832.70                1
# 3                   1         2.0        745.55                1
# 4                   0         2.0        684.12                1
# ...               ...         ...           ...              ...
# 20058               1         2.0        869.61                0
# 20059               0         3.0        729.41                0
# 20060               1         3.0        677.27                0
# 20061               1         3.0        677.27                1
# 20062               1         1.0        815.44                0
#
#        Has Active Credit Card  Property Location  Co-Applicant  Property Price
# 0                           2                  0           1.0       119933.46
# 1                           2                  0           1.0        54791.00
# 2                           2                  1           1.0       121441.51
# 3                           0                  1           1.0       208567.91
# 4                           1                  0           1.0        43146.82
# ...                       ...                ...           ...             ...
# 20058                       2                  2           1.0       111096.56
# 20059                       1                  2           1.0        73453.94
# 20060                       0                  0           1.0       102108.02
# 20061                       2                  2           1.0       168194.47
# 20062                       0                  0           1.0       194512.60
#
# [20063 rows x 16 columns]

# %%
# defining the dependent variable
y = data['Loan Sanction Amount (USD)']
y
# Out:
# 0         54607.18
# 1         37469.98
# 2         56040.54
# 3         74008.28
# 4         22382.57
#            ...
# 20058     68992.11
# 20059     46616.60
# 20060     61057.56
# 20061     99766.87
# 20062    117217.90
# Name: Loan Sanction Amount (USD), Length: 20063, dtype: float64

# %%
# splitting the data into train and test data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
# training the model
DTR.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
# making predictions using the test data
predictions = DTR.predict(X_test)

# %%
# measuring the r2 score of the trained model
from sklearn.metrics import r2_score

# score = DTR.score(X_test, y_test)

r2_score(y_test, predictions)
# Out:
# 0.9362287012804633

# %%
# plotting a scatter plot of the test output vs the predicted output
import matplotlib.pyplot as plt

plt.scatter(y_test, predictions)
plt.xlabel('test data')
plt.ylabel('predicted data')

plt.show()
