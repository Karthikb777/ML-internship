# %% [markdown]
# # Training and testing the model.
# ## Model used: Linear Regression

# %%
# importing the cleaned data 
import pandas as pd

data = pd.read_csv('../encoded data/enc1.csv')
data
# Out:
#        Unnamed: 0  Age  Income (USD)  Income Stability  Type of Employment  \
# 0               0   56       1933.05                 1                  14
# 1               1   32       4952.91                 1                   6
# 2               3   65       2614.77                 0                   6
# 3               4   31       2614.77                 1                   6
# 4               5   60       1234.92                 1                  15
# ...           ...  ...           ...               ...                 ...
# 20058       29995   38       4969.41                 1                  10
# 20059       29996   20       1606.88                 1                   8
# 20060       29997   49       2417.71                 1                  14
# 20061       29998   38       2417.71                 1                  16
# 20062       29999   63       3068.24                 0                  18
#
#        Location  Loan Amount Request (USD)  Current Loan Expenses (USD)  \
# 0             1                   72809.58                       241.08
# 1             1                   46837.47                       495.81
# 2             0                   80057.92                       298.54
# 3             1                  113858.89                       491.41
# 4             0                   34434.72                       181.48
# ...         ...                        ...                          ...
# 20058         2                   76657.90                       722.34
# 20059         1                   66595.14                       253.04
# 20060         2                   81410.08                       583.11
# 20061         1                  142524.10                       378.29
# 20062         0                  156290.54                       693.94
#
#        Expense Type 1  Expense Type 2  Dependents  Credit Score  \
# 0                   0               0         3.0        809.44
# 1                   0               1         1.0        780.40
# 2                   0               1         2.0        832.70
# 3                   0               1         2.0        745.55
# 4                   0               0         2.0        684.12
# ...               ...             ...         ...           ...
# 20058               1               1         2.0        869.61
# 20059               0               0         3.0        729.41
# 20060               0               1         3.0        677.27
# 20061               0               1         3.0        677.27
# 20062               0               1         1.0        815.44
#
#        No. of Defaults  Has Active Credit Card  Property Location  \
# 0                    0                       2                  0
# 1                    0                       2                  0
# 2                    1                       2                  1
# 3                    1                       0                  1
# 4                    1                       1                  0
# ...                ...                     ...                ...
# 20058                0                       2                  2
# 20059                0                       1                  2
# 20060                0                       0                  0
# 20061                1                       2                  2
# 20062                0                       0                  0
#
#        Co-Applicant  Property Price  Loan Sanction Amount (USD)
# 0               1.0       119933.46                    54607.18
# 1               1.0        54791.00                    37469.98
# 2               1.0       121441.51                    56040.54
# 3               1.0       208567.91                    74008.28
# 4               1.0        43146.82                    22382.57
# ...             ...             ...                         ...
# 20058           1.0       111096.56                    68992.11
# 20059           1.0        73453.94                    46616.60
# 20060           1.0       102108.02                    61057.56
# 20061           1.0       168194.47                    99766.87
# 20062           1.0       194512.60                   117217.90
#
# [20063 rows x 18 columns]

# %%
# importing and creating the object of the regression model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# defining the independent variables 
X = data.drop(['Loan Sanction Amount (USD)', 'Unnamed: 0'], axis=1)
X
# Out:
#        Age  Income (USD)  Income Stability  Type of Employment  Location  \
# 0       56       1933.05                 1                  14         1
# 1       32       4952.91                 1                   6         1
# 2       65       2614.77                 0                   6         0
# 3       31       2614.77                 1                   6         1
# 4       60       1234.92                 1                  15         0
# ...    ...           ...               ...                 ...       ...
# 20058   38       4969.41                 1                  10         2
# 20059   20       1606.88                 1                   8         1
# 20060   49       2417.71                 1                  14         2
# 20061   38       2417.71                 1                  16         1
# 20062   63       3068.24                 0                  18         0
#
#        Loan Amount Request (USD)  Current Loan Expenses (USD)  Expense Type 1  \
# 0                       72809.58                       241.08               0
# 1                       46837.47                       495.81               0
# 2                       80057.92                       298.54               0
# 3                      113858.89                       491.41               0
# 4                       34434.72                       181.48               0
# ...                          ...                          ...             ...
# 20058                   76657.90                       722.34               1
# 20059                   66595.14                       253.04               0
# 20060                   81410.08                       583.11               0
# 20061                  142524.10                       378.29               0
# 20062                  156290.54                       693.94               0
#
#        Expense Type 2  Dependents  Credit Score  No. of Defaults  \
# 0                   0         3.0        809.44                0
# 1                   1         1.0        780.40                0
# 2                   1         2.0        832.70                1
# 3                   1         2.0        745.55                1
# 4                   0         2.0        684.12                1
# ...               ...         ...           ...              ...
# 20058               1         2.0        869.61                0
# 20059               0         3.0        729.41                0
# 20060               1         3.0        677.27                0
# 20061               1         3.0        677.27                1
# 20062               1         1.0        815.44                0
#
#        Has Active Credit Card  Property Location  Co-Applicant  Property Price
# 0                           2                  0           1.0       119933.46
# 1                           2                  0           1.0        54791.00
# 2                           2                  1           1.0       121441.51
# 3                           0                  1           1.0       208567.91
# 4                           1                  0           1.0        43146.82
# ...                       ...                ...           ...             ...
# 20058                       2                  2           1.0       111096.56
# 20059                       1                  2           1.0        73453.94
# 20060                       0                  0           1.0       102108.02
# 20061                       2                  2           1.0       168194.47
# 20062                       0                  0           1.0       194512.60
#
# [20063 rows x 16 columns]

# %%
# defining the dependent variable
Y = data['Loan Sanction Amount (USD)']
Y
# Out:
# 0         54607.18
# 1         37469.98
# 2         56040.54
# 3         74008.28
# 4         22382.57
#            ...
# 20058     68992.11
# 20059     46616.60
# 20060     61057.56
# 20061     99766.87
# 20062    117217.90
# Name: Loan Sanction Amount (USD), Length: 20063, dtype: float64

# %%
# splitting the dataset into training and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=101) 

# test size determines the split between training and testing data.
#  here 20% of the data is the testing data.
#  remaining 80% of the data is the training data.

# %%
X_train
# Out:
#        Age  Income (USD)  Income Stability  Type of Employment  Location  \
# 19700   60       2224.29                 1                   8         1
# 15760   18        934.00                 1                  15         1
# 16146   27        837.18                 1                   3         1
# 13937   18       2254.92                 1                   8         2
# 16645   18       3524.23                 1                   8         2
# ...    ...           ...               ...                 ...       ...
# 5695    45       6658.52                 1                   3         1
# 8006    64       2451.97                 1                  14         1
# 17745   52       1608.08                 1                   4         0
# 17931   18       5411.25                 1                   6         1
# 13151   32       1722.18                 1                   3         1
#
#        Loan Amount Request (USD)  Current Loan Expenses (USD)  Expense Type 1  \
# 19700                   94575.64                       433.72               0
# 15760                   19034.26                        96.29               1
# 16146                   51443.55                       236.04               1
# 13937                  151454.60                       605.46               1
# 16645                   40890.25                       309.40               0
# ...                          ...                          ...             ...
# 5695                   124178.71                       481.02               0
# 8006                    68011.61                       377.80               0
# 17745                   76558.73                       440.37               1
# 17931                  220802.74                      1062.19               1
# 13151                  148729.86                       520.71               0
#
#        Expense Type 2  Dependents  Credit Score  No. of Defaults  \
# 19700               1         1.0        677.17                0
# 15760               1         4.0        697.24                0
# 16146               1         3.0        654.10                0
# 13937               1         2.0        806.19                0
# 16645               1         2.0        684.09                0
# ...               ...         ...           ...              ...
# 5695                0         2.0        665.56                1
# 8006                1         4.0        675.21                0
# 17745               1         2.0        797.22                0
# 17931               0         2.0        764.32                1
# 13151               1         4.0        829.94                0
#
#        Has Active Credit Card  Property Location  Co-Applicant  Property Price
# 19700                       1                  1           1.0       165468.52
# 15760                       2                  1           1.0        27495.06
# 16146                       0                  2           1.0        79917.49
# 13937                       1                  2           1.0       230100.70
# 16645                       0                  2           1.0        68526.69
# ...                       ...                ...           ...             ...
# 5695                        2                  1           1.0       144640.90
# 8006                        0                  0           1.0        77242.59
# 17745                       2                  1           1.0       142244.38
# 17931                       2                  0           1.0       327343.65
# 13151                       0                  0           1.0       204175.53
#
# [16050 rows x 16 columns]

# %%
# training the model
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# testing the model
predictions = model.predict(X_test)

# %%
# getting the r2 score of the trained model
from sklearn.metrics import r2_score
r2_score(Y_test, predictions)
# Out:
# 0.9693971794711593

# %%
# plotting a scatter plot of the test output vs the predicted output

import matplotlib.pyplot as plt

plt.scatter(Y_test, predictions)
plt.xlabel('test data')
plt.ylabel('predicted data')

plt.show()

# %% [markdown]
# ### Saving the trained model to a pickle file
# Here we are serializing the trained model and saving it using pickle, so that we can use it later or in another file to deploy the model to production.

# %%
import pickle

# %%
filepath = open('../pickles/linearRegression.pickle', 'wb')
pickle.dump(model, filepath)
